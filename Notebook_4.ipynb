# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'data/worldcities.csv')
df.head()
# Out:
#           city   city_ascii      lat       lng        country iso2 iso3  \
# 0        Tokyo        Tokyo  35.6850  139.7514          Japan   JP  JPN
# 1     New York     New York  40.6943  -73.9249  United States   US  USA
# 2  Mexico City  Mexico City  19.4424  -99.1310         Mexico   MX  MEX
# 3       Mumbai       Mumbai  19.0170   72.8570          India   IN  IND
# 4    São Paulo    Sao Paulo -23.5587  -46.6250         Brazil   BR  BRA
#
#          admin_name  capital  population          id
# 0             Tōkyō  primary  35676000.0  1392685764
# 1          New York      NaN  19354922.0  1840034016
# 2  Ciudad de México  primary  19028000.0  1484247881
# 3       Mahārāshtra    admin  18978000.0  1356226629
# 4         São Paulo    admin  18845000.0  1076532519

# %%
df.shape
# Out:
# (15493, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15493 entries, 0 to 15492
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        15493 non-null  object
#  1   city_ascii  15493 non-null  object
#  2   lat         15493 non-null  float64
#  3   lng         15493 non-null  float64
#  4   country     15493 non-null  object
#  5   iso2        15462 non-null  object
#  6   iso3        15493 non-null  object
#  7   admin_name  15302 non-null  object
#  8   capital     5246 non-null   object
#  9   population  13808 non-null  float64
#  10  id          15493 non-null  int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df.describe(include='all')
# Out:
#            city city_ascii           lat           lng        country   iso2  \
# count     15493      15493  15493.000000  15493.000000          15493  15462
# unique    13504      13482           NaN           NaN            223    222
# top     Clinton    Clinton           NaN           NaN  United States     US
# freq         13         13           NaN           NaN           7328   7328
# mean        NaN        NaN     29.633315    -29.834189            NaN    NaN
# std         NaN        NaN     22.414727     76.340457            NaN    NaN
# min         NaN        NaN    -54.933300   -179.590000            NaN    NaN
# 25%         NaN        NaN     22.305000    -86.324200            NaN    NaN
# 50%         NaN        NaN     37.756200    -71.916700            NaN    NaN
# 75%         NaN        NaN     42.444200     25.582100            NaN    NaN
# max         NaN        NaN     82.483300    179.383300            NaN    NaN
#
# ...

# %%
df.groupby(['country','capital','city']).count()
# Out:
#                                city_ascii  lat  lng  iso2  iso3  admin_name  \
# country     capital city
# Afghanistan admin   Asadābād            1    1    1     1     1           1
#                     Aībak               1    1    1     1     1           1
#                     Bāmyān              1    1    1     1     1           1
#                     Bāzārak             1    1    1     1     1           1
#                     Chārīkār            1    1    1     1     1           1
# ...                                   ...  ...  ...   ...   ...         ...
# Zimbabwe    admin   Lupane              1    1    1     1     1           1
#                     Marondera           1    1    1     1     1           1
#                     Masvingo            1    1    1     1     1           1
#                     Mutare              1    1    1     1     1           1
#             primary Harare              1    1    1     1     1           1
#
# ...

# %%
df_cap = df[df.capital == 'primary']
df_cap.reset_index(drop=True,inplace=True)
df_cap.head()
# Out:
#            city    city_ascii      lat       lng     country iso2 iso3  \
# 0         Tokyo         Tokyo  35.6850  139.7514       Japan   JP  JPN
# 1   Mexico City   Mexico City  19.4424  -99.1310      Mexico   MX  MEX
# 2         Dhaka         Dhaka  23.7231   90.4086  Bangladesh   BD  BGD
# 3  Buenos Aires  Buenos Aires -34.6025  -58.3975   Argentina   AR  ARG
# 4         Cairo         Cairo  30.0500   31.2500       Egypt   EG  EGY
#
#                          admin_name  capital  population          id
# 0                             Tōkyō  primary  35676000.0  1392685764
# 1                  Ciudad de México  primary  19028000.0  1484247881
# 2                             Dhaka  primary  12797394.0  1050529279
# 3  Buenos Aires, Ciudad Autónoma de  primary  12795000.0  1032717330
# 4                        Al Qāhirah  primary  11893000.0  1818253931

# %%
df_cap.columns
# Out:
# Index(['country', 'capital', 'iso3', 'lat', 'lng', 'admin_name'], dtype='object')

# %%
new_order = ['country','city','iso3','lat','lng','admin_name']

# %%
df_cap = df_cap[new_order]
df_cap.head()
# Out:
#       country          city iso3      lat       lng  \
# 0       Japan         Tokyo  JPN  35.6850  139.7514
# 1      Mexico   Mexico City  MEX  19.4424  -99.1310
# 2  Bangladesh         Dhaka  BGD  23.7231   90.4086
# 3   Argentina  Buenos Aires  ARG -34.6025  -58.3975
# 4       Egypt         Cairo  EGY  30.0500   31.2500
#
#                          admin_name
# 0                             Tōkyō
# 1                  Ciudad de México
# 2                             Dhaka
# 3  Buenos Aires, Ciudad Autónoma de
# 4                        Al Qāhirah

# %%
df_cap = df_cap.sort_values(by='country')
df_cap.head()
# Out:
#             country              city iso3      lat       lng  \
# 35      Afghanistan             Kabul  AFG  34.5167   69.1833
# 112         Albania            Tirana  ALB  41.3275   19.8189
# 32          Algeria           Algiers  DZA  36.7631    3.0506
# 201  American Samoa         Pago Pago  ASM -14.2740 -170.7046
# 184         Andorra  Andorra la Vella  AND  42.5000    1.5165
#
#            admin_name
# 35              Kābul
# 112            Tiranë
# 32              Alger
# 201               NaN
# 184  Andorra la Vella

# %%
df_cap.reset_index(drop=True,inplace=True)

# %%
df_cap.head()
# Out:
#           country              city iso3      lat       lng        admin_name
# 0     Afghanistan             Kabul  AFG  34.5167   69.1833             Kābul
# 1         Albania            Tirana  ALB  41.3275   19.8189            Tiranë
# 2         Algeria           Algiers  DZA  36.7631    3.0506             Alger
# 3  American Samoa         Pago Pago  ASM -14.2740 -170.7046               NaN
# 4         Andorra  Andorra la Vella  AND  42.5000    1.5165  Andorra la Vella

# %%
df_cap = df_cap.rename(columns={'city':'capital'})
df_cap.head()
# Out:
#           country           capital iso3      lat       lng        admin_name
# 0     Afghanistan             Kabul  AFG  34.5167   69.1833             Kābul
# 1         Albania            Tirana  ALB  41.3275   19.8189            Tiranë
# 2         Algeria           Algiers  DZA  36.7631    3.0506             Alger
# 3  American Samoa         Pago Pago  ASM -14.2740 -170.7046               NaN
# 4         Andorra  Andorra la Vella  AND  42.5000    1.5165  Andorra la Vella

# %%
df_cap.shape
# Out:
# (212, 6)

# %%
df_cap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     212 non-null    object
#  1   capital     212 non-null    object
#  2   iso3        212 non-null    object
#  3   lat         212 non-null    float64
#  4   lng         212 non-null    float64
#  5   admin_name  197 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 10.1+ KB

# %%
df_cap['admin_name'].fillna(df_cap['capital'],inplace=True)
df_cap.head()
# Out:
#           country           capital iso3      lat       lng        admin_name
# 0     Afghanistan             Kabul  AFG  34.5167   69.1833             Kābul
# 1         Albania            Tirana  ALB  41.3275   19.8189            Tiranë
# 2         Algeria           Algiers  DZA  36.7631    3.0506             Alger
# 3  American Samoa         Pago Pago  ASM -14.2740 -170.7046         Pago Pago
# 4         Andorra  Andorra la Vella  AND  42.5000    1.5165  Andorra la Vella

# %%
df_cap.loc[df_cap.country == 'Cuba']
# Out:
#    country capital iso3     lat      lng admin_name
# 49    Cuba  Havana  CUB  23.132 -82.3642  La Habana

# %%
df_cap.loc[df_cap.iso3 == 'MEX']
# Out:
#     country      capital iso3      lat     lng        admin_name
# 122  Mexico  Mexico City  MEX  19.4424 -99.131  Ciudad de México

# %%
df.loc[df.country == 'Haiti']#.groupby(['country','city']).count()
# Out:
#                 city      city_ascii      lat      lng country iso2 iso3  \
# 216   Port-au-Prince  Port-au-Prince  18.5410 -72.3360   Haiti   HT  HTI
# 1641     Cap-Haïtien     Cap-Haitien  19.7592 -72.2125   Haiti   HT  HTI
# 2305       Les Cayes       Les Cayes  18.2004 -73.7500   Haiti   HT  HTI
# 2384        Gonaïves        Gonaives  19.4504 -72.6832   Haiti   HT  HTI
# 4223    Port-de-Paix    Port-de-Paix  19.9318 -72.8295   Haiti   HT  HTI
# 4261          Jacmel          Jacmel  18.2350 -72.5370   Haiti   HT  HTI
# 4322         Jérémie         Jeremie  18.6339 -74.1184   Haiti   HT  HTI
# 4681          Hinche          Hinche  19.1430 -72.0040   Haiti   HT  HTI
# 4953    Fort Liberté    Fort Liberte  19.6656 -71.8448   Haiti   HT  HTI
# 6017       Miragoâne       Miragoane  18.4411 -73.0883   Haiti   HT  HTI
#
#       admin_name  capital  population          id
# 216        Ouest  primary   1998000.0  1332401940
# 1641        Nord    admin    281487.0  1332333795
# ...

# %%
df.columns.to_list()
# Out:
# ['city',
#  'city_ascii',
#  'lat',
#  'lng',
#  'country',
#  'iso2',
#  'iso3',
#  'admin_name',
#  'capital',
#  'population',
#  'id']

# %%
order = ['country','admin_name','city',
 'city_ascii',
 'lat',
 'lng',
 'iso2',
 'iso3',
 'capital',
 'population',
 'id']

# %%
df = df[order]
df.head()
# Out:
#          country        admin_name         city   city_ascii      lat  \
# 0          Japan             Tōkyō        Tokyo        Tokyo  35.6850
# 1  United States          New York     New York     New York  40.6943
# 2         Mexico  Ciudad de México  Mexico City  Mexico City  19.4424
# 3          India       Mahārāshtra       Mumbai       Mumbai  19.0170
# 4         Brazil         São Paulo    São Paulo    Sao Paulo -23.5587
#
#         lng iso2 iso3  capital  population          id
# 0  139.7514   JP  JPN  primary  35676000.0  1392685764
# 1  -73.9249   US  USA      NaN  19354922.0  1840034016
# 2  -99.1310   MX  MEX  primary  19028000.0  1484247881
# 3   72.8570   IN  IND    admin  18978000.0  1356226629
# 4  -46.6250   BR  BRA    admin  18845000.0  1076532519

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.loc[df.country == 'Haiti'].groupby(['country','admin_name','city','city_ascii','population']).count()
# Out:
#                                                              lat  lng  iso2  \
# country admin_name city           city_ascii     population
# Haiti   Artibonite Gonaïves       Gonaives       166678.0      1    1     1
#         Centre     Hinche         Hinche         18590.0       1    1     1
#         Grand’Anse Jérémie        Jeremie        30917.0       1    1     1
#         Nord       Cap-Haïtien    Cap-Haitien    281487.0      1    1     1
#         Nord-Est   Fort Liberté   Fort Liberte   11465.0       1    1     1
#         Nord-Ouest Port-de-Paix   Port-de-Paix   34657.0       1    1     1
#         Ouest      Port-au-Prince Port-au-Prince 1998000.0     1    1     1
#         Sud        Les Cayes      Les Cayes      175457.0      1    1     1
#         Sud-Est    Jacmel         Jacmel         33563.0       1    1     1
#
#                                                              iso3  capital  id
# country admin_name city           city_ascii     population
# ...
